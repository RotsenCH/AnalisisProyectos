# %% [markdown]
# ## Analisis Descriptivo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
data = pd.read_csv('./data_original/covid_table.csv')
print('Original data')
print((data.size, 4))
print(data.head(5))
# Out:
# Original data
# (5681, 4)
#    Unnamed: 0   # Country, Other  Total Cases  New Cases  Total Deaths  \
# 0           0 NaN  North America    124713684     1375.0     1612527.0
# 1           1 NaN           Asia    214474070    34365.0     1537319.0
# 2           2 NaN         Europe    246559618    28857.0     2019348.0
# 3           3 NaN  South America     68045724     3031.0     1350925.0
# 4           4 NaN        Oceania     14015805        NaN       26203.0
#
#    New Deaths  Total Recovered  New Recovered  Active Cases  ...  Total Tests  \
# 0         5.0      120000633.0         4075.0     3100524.0  ...          NaN
# 1       172.0      199108565.0        53192.0    13828186.0  ...          NaN
# 2        65.0      242096217.0        28694.0     2444053.0  ...          NaN
# 3        19.0       66293552.0           90.0      401247.0  ...          NaN
# 4         NaN       13852354.0            NaN      137248.0  ...          NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           247 non-null    int64
#  1   #                    231 non-null    float64
#  2   Country, Other       246 non-null    object
#  3   Total Cases          247 non-null    int64
#  4   New Cases            46 non-null     float64
#  5   Total Deaths         241 non-null    float64
#  6   New Deaths           28 non-null     float64
#  7   Total Recovered      226 non-null    float64
#  8   New Recovered        44 non-null     float64
#  9   Active Cases         228 non-null    float64
#  10  Serious, Critical    143 non-null    float64
#  11  Tot Cases/ 1M pop    231 non-null    float64
#  12  Deaths/ 1M pop       225 non-null    float64
#  13  Total Tests          213 non-null    float64
#  14  Tests/ 1M pop        213 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0           #   Total Cases     New Cases  Total Deaths  \
# count   247.00000  231.000000  2.470000e+02     46.000000  2.410000e+02
# mean    123.00000  116.000000  1.377745e+07   7353.586957  1.411811e+05
# std      71.44695   66.828138  6.858925e+07  15873.790150  6.843786e+05
# min       0.00000    1.000000  5.000000e+00      2.000000  1.000000e+00
# 25%      61.50000   58.500000  2.634950e+04     50.000000  2.270000e+02
# 50%     123.00000  116.000000  2.510710e+05    332.500000  2.805000e+03
# 75%     184.50000  173.500000  1.950603e+06   3787.750000  1.987800e+04
# max     246.00000  231.000000  6.806060e+08  67653.000000  6.804927e+06
#
#        New Deaths  Total Recovered  New Recovered  Active Cases  \
# count   28.000000     2.260000e+02      44.000000  2.280000e+02
# mean    46.607143     1.437244e+07    9790.613636  4.398302e+05
# std     76.366242     6.874506e+07   21189.292201  2.426630e+06
# ...

# %%
sns.histplot(data=data, x='Total Deaths', stat='frequency')
plt.show()

# %%
data.isnull()
# Out:
#      Unnamed: 0     #  Country, Other  Total Cases  New Cases  Total Deaths  \
# 0         False  True           False        False      False         False
# 1         False  True           False        False      False         False
# 2         False  True           False        False      False         False
# 3         False  True           False        False      False         False
# 4         False  True           False        False       True         False
# ..          ...   ...             ...          ...        ...           ...
# 242       False  True           False        False      False         False
# 243       False  True           False        False       True         False
# 244       False  True           False        False      False         False
# 245       False  True           False        False       True         False
# 246       False  True           False        False      False         False
#
# ...

# %%
msno.bar(data)
# Out:
# <Axes: >

# %%
data.drop(['New Cases', 'New Deaths', 'New Recovered', 'Active Cases/1M pop', 'New Deaths/1M pop'], axis=1,inplace=True)
data
# Out:
#      Unnamed: 0   # Country, Other  Total Cases  Total Deaths  \
# 0             0 NaN  North America    124713684     1612527.0
# 1             1 NaN           Asia    214474070     1537319.0
# 2             2 NaN         Europe    246559618     2019348.0
# 3             3 NaN  South America     68045724     1350925.0
# 4             4 NaN        Oceania     14015805       26203.0
# ..          ...  ..            ...          ...           ...
# 242         242 NaN         Total:     68045724     1350925.0
# 243         243 NaN         Total:     14015805       26203.0
# 244         244 NaN         Total:     12796351      258590.0
# 245         245 NaN         Total:          721          15.0
# 246         246 NaN         Total:    680605973     6804927.0
#
#      Total Recovered  Active Cases  Serious, Critical  Tot Cases/ 1M pop  \
# 0        120000633.0     3100524.0             7892.0                NaN
# ...

# %%
prueba1 = data.dropna()
prueba1
# Out:
#      Unnamed: 0      # Country, Other  Total Cases  Total Deaths  \
# 8             8    1.0            USA    105393864     1146728.0
# 10           10    3.0         France     39638159      165030.0
# 13           13    6.0          Japan     33251497       72721.0
# 14           14    7.0       S. Korea     30555102       34020.0
# 20           20   13.0        Vietnam     11526962       43186.0
# 28           28   21.0         Poland      6431888      118952.0
# 30           30   23.0        Austria      5936666       21921.0
# 34           34   27.0          Chile      5177770       64222.0
# 35           35   28.0       Malaysia      5043626       36965.0
# 36           36   29.0         Israel      4801230       12303.0
# 40           40   33.0        Czechia      4613882       42464.0
# 42           42   35.0           Peru      4486665      219485.0
# 44           44   37.0    Philippines      4076866       66143.0
# ...

# %%
sns.histplot(data=prueba1, x='Total Deaths', stat='count')
plt.show()

# %%
sns.boxplot(data=prueba1, x='Total Deaths', dodge=True)
plt.show()

# %%
sns.boxplot(data=prueba1, x='Total Cases', dodge=True)
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(prueba1.corr(), annot=True)
plt.show()
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_31952\3969244289.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(prueba1.corr(), annot=True)

# %%
prueba1.to_csv('./data_clean/covid.csv')
